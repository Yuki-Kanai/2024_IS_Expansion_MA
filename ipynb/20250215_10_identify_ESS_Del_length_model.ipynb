# %% [markdown]
# Lee++ (NAR, 2016) says that IS*1* undertakes "local hopping".
# Here, I aim to analyze whether the distribution of essential genes contribute to the local hopping.
#
# # Overview
#
# 1. Load data
# 2. Identify esseitnal genes (using blastn)
# 3. Calculate average distance from the closest essential gene and compare with deletion length
#
# ### Input
# Deletion boundary and corresponding IS IDs.
# List of ranges of essential genes.
#
# ### Procedure
# 1. Identify new-existing type deletions (MA8, MA20).
# 2. Identify homologous sequences to the essential regions
# 	1. blast homologous genes
# 	2. remove the duplicates
# 	3. output closest essential genes for each IS
# 3. Identify distances to the closest essential region.

# %% [markdown]
# # Loading

# %%
import os
import subprocess
import numpy as np
import pandas as pd
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# %% [markdown]
# ## List of Essential genes
# note that gene_df... is in the coordinates of MDS42_IS1.fa starting from thrC.

# %%
# Inputs
# get essential genes
essential_genes_file = os.path.join("..","misc","gene_df_ess_mds42_based_on_PEC.csv")
essential_genes = pd.read_csv(essential_genes_file)
essential_genes = essential_genes[["gene", "start", "end", "Essential_PEC"]]
essential_genes = essential_genes[essential_genes["Essential_PEC"] == True].\
			reset_index(drop=True)

# get MDS42 sequences
mds42_fasta = os.path.join("..","fasta","20230904","MDS42_IS1.fa")

essential_genes.head()
# Out:
#    gene  start    end Essential_PEC
# 0  ribF  16232  17173          True
# 1  ileS  17216  20032          True
# 2  lspA  20032  20526          True
# 3  ispH  21102  22052          True
# 4  dapB  23199  24020          True

# %% [markdown]
# ## IS positions

# %%
base_output_dir = os.path.join("exp", "multiple_runs14")
base_export = os.path.join(base_output_dir, "export")
data_export_dir = os.path.join(base_output_dir, "data", "ins_del_analysis")
file_name_base = "20250204_"
is_positions_df = os.path.join(base_export, "classify_IS_events", "IS_positions.csv")
is_positions_df = pd.read_csv(is_positions_df)
is_positions_df = is_positions_df.rename(columns = {"Gen":"gen_id", "Line":"line"})
is_positions_df.head()
# Out:
#      start      end IS_strand  max_alignment_length  length  cluster_id  \
# 0   476928   480020   reverse                  3093    3093           0
# 1   557167   560259   reverse                  3093    3093           1
# 2  1187831  1192502   forward                  3093    4672           2
# 3  1405123  1408215   forward                  3093    3093           3
# 4  1499230  1503892   reverse                  3093    4663           4
#
#     line  gen_id
# 0  L01-1       1
# 1  L01-1       1
# 2  L01-1       1
# 3  L01-1       1
# 4  L01-1       1

# %% [markdown]
# ## Genome size

# %%
genome_sizes = os.path.join(base_export, "classify_IS_events", "genome_stats.csv")
genome_sizes = pd.read_csv(genome_sizes)
genome_sizes = genome_sizes[['Prefix', 'gen_id', 'genome_size', 'is_cnt']]
genome_sizes = genome_sizes.rename(columns = {"Prefix":"line"})
genome_sizes.head()
# Out:
#     line  gen_id  genome_size  is_cnt
# 0  L01-1       1      4003851      10
# 1  L01-2       1      4003851      10
# 2  L01-3       1      4003851      10
# 3  L01-4       1      4003851      10
# 4  L02-1       1      4026846      15

# %% [markdown]
# ## Deletion length distributions

# %%
deletion_df = os.path.join(base_export, "classify_IS_events", "depth_interval.csv")
deletion_df = pd.read_csv(deletion_df)
deletion_df = deletion_df[['line', 'gen_id', 'group', 'start_fix', 'end_fix', 'is_start', 'is_end', 'depth']]
deletion_df = deletion_df.rename(columns = {"start_fix":"start", "end_fix":"end"})
deletion_df = deletion_df.query('depth == 0').drop(columns = ['depth'])
deletion_df.head()
# Out:
#      line  gen_id  group    start      end  is_start  is_end
# 1   L01-1       2      2   552531   560570         3       6
# 5   L01-1       2      6  2661331  2665538        21      22
# 8   L01-1       3      2   552054   552515         3       4
# 10  L01-1       3      4  1676263  1680759        18      21
# 12  L01-1       3      6  1791833  1792427        24      25

# %%
is_pos_in_ref_genome = os.path.join(base_export, "classify_IS_events", "IS_positions_in_ref_genome.csv")
is_pos_in_ref_genome = pd.read_csv(is_pos_in_ref_genome)
# Line, Gen, insert_id, genome, pos_id, IS_strand, position_status
is_pos_in_ref_genome = is_pos_in_ref_genome[['Gen', 'Line', 'insert_id', 'genome', 'pos_id', 'IS_strand', 'position_status']]
is_pos_in_ref_genome = is_pos_in_ref_genome.rename(columns = {"Gen":"gen_id", "Line":"line"})
is_pos_in_ref_genome = is_pos_in_ref_genome.query('genome == "Query"')
is_pos_in_ref_genome.query('position_status == "new"').head()
# Out:
#     gen_id   line  insert_id genome  pos_id  IS_strand position_status
# 22       2  L01-1          3  Query       1      False             new
# 23       2  L01-1          6  Query       1      False             new
# 24       2  L01-1          7  Query       2      False             new
# 25       2  L01-1          7  Query       2      False             new
# 27       2  L01-1         10  Query       3      False             new

# %% [markdown]
# # Identify essential genes
#
# ### Procedure
# 1. For each genome (line_id, gen_id)
# 2. Build blastdb and run blast with essential genes of MDS42 (PEC database) as query
# 3. Identify duplicated and missing essential genes
#
# ### Output:
# - `merged_df`: Detailed alignment results including information about each significant match found during the BLAST searches.
# - `summarised_df`: A summary report indicating the number of duplicated and missing essential genes for each line and genome analyzed.
#
# ## Misc functions

# %%
def create_blast_db(ref_fasta, db_dir, prefix, overwrite=False):
    """
    Create a BLAST database from a reference fasta file.
    :param ref_fasta: Path to the reference fasta file.
    :param db_dir: Directory where the BLAST database should be stored.
    :param prefix: Prefix to identify the database.
    """
    db_path = os.path.join(db_dir, prefix)
    command = ['makeblastdb', '-in', ref_fasta, '-dbtype', 'nucl', '-out', db_path]
    subprocess.run(command, check=True)
    return db_path

def run_blast(query_fasta, db_path, output_path):
    """
    Run BLASTn using a query fasta file against a BLAST database.
    :param query_fasta: Path to the query fasta file.
    :param db_path: Path to the BLAST database.
    :param output_path: Path to save the BLAST output.
    """
    command = [
        'blastn', '-query', query_fasta, '-db', db_path, 
        '-outfmt', '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen', 
        '-out', output_path
    ]
    subprocess.run(command, check=True)
    # add column names to the csv. currently data starts from the first row
    with open(output_path, 'r') as f:
        data = f.read()
    with open(output_path, 'w') as f:
        #tsv
        #f.write('qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen\n')
        f.write('qseqid\tsseqid\tpident\tlength\tmismatch\tgapopen\tqstart\tqend\tsstart\tsend\tevalue\tbitscore\tqlen\n')
        f.write(data)
    return output_path

def create_query_fasta(df, reference_fasta, output_fasta):
    """
    Create a query FASTA file from a pandas DataFrame containing start and end positions.
    :param df: DataFrame with columns ['Name', 'Start', 'End'].
    :param output_fasta: Path to the output FASTA file.
    """
    os.makedirs(os.path.dirname(output_fasta), exist_ok=True)
    records = []
    reference_seq = SeqIO.read(reference_fasta, "fasta").seq
    for index, row in df.iterrows():
    	sequence = reference_seq[row['start']:row['end']]
    	record = SeqRecord(Seq(sequence), id=row['gene'], description="")
    	records.append(record)
    SeqIO.write(records, output_fasta, "fasta")
    return output_fasta

def run_ess_blast(prefix, ref_fasta, query_fasta, tmp_dir):
	db_dir = os.path.join(tmp_dir, 'blastdb')
	output_dir = os.path.join(tmp_dir, 'blast-ess')
	result_csv = os.path.join(output_dir, f'{prefix}.blast-ess.csv')
	os.makedirs(db_dir, exist_ok=True)
	os.makedirs(output_dir, exist_ok=True)
	db_path = create_blast_db(ref_fasta, db_dir, prefix)
	run_blast(query_fasta, db_path, result_csv) # tsv
	return result_csv

# %% [markdown]
# ## Main function

# %%
def identify_ess_genes(line_df, query_fasta, essential_genes, base_output_dir, tmp_dir):
	merged_df = pd.DataFrame()
	summarised_df = pd.DataFrame()
	for index, row in line_df.iterrows():
		line_id = row['line']
		gen_id = row['gen_id']

		res_csv_ = run_ess_blast(f'{line_id}.{gen_id}',\
			os.path.join(base_output_dir, "tmp", line_id, f'{line_id}_genome.{gen_id}.fasta'),\
			query_fasta, tmp_dir)
		res_ess_ = pd.read_csv(res_csv_, sep='\t')

		# filter partial matches
		threshold_length = 5
		threshold_ratio = 0.95
		threshold_evalue = 1e-10
		res_ess_ = res_ess_[(res_ess_['length'] > res_ess_['qlen'] - threshold_length) |\
			(res_ess_['length'] / res_ess_['qlen'] > threshold_ratio)]
		res_ess_ = res_ess_[(res_ess_['evalue'] < threshold_evalue)]

		res_ess_['line'] = line_id
		res_ess_['gen_id'] = gen_id
		# reorder by length
		res_ess_ = res_ess_.sort_values(by=['length'], ascending=False)
		res_ess_['duplicated'] = res_ess_.duplicated(subset=['qseqid'], keep=False)
		res_ess_ = res_ess_.rename(columns={'qseqid': 'gene'}).\
			drop(columns=['sseqid'])
		merged_df = pd.concat([merged_df, res_ess_], ignore_index=True)

		duplicated_genes = res_ess_[res_ess_['duplicated']]['gene'].unique()
		missing_genes = essential_genes[~essential_genes['gene'].isin(res_ess_['gene'])]
		summarised_df = pd.concat([summarised_df, pd.DataFrame({
			'line': [line_id],
			'gen_id': [gen_id],
			'duplicated_genes': [len(duplicated_genes)],
			'missing_genes': [len(missing_genes)], 
		})], ignore_index=True)

	#reindex 
	merged_df = merged_df.reset_index(drop=True)
	summarised_df = summarised_df.reset_index(drop=True)
	return merged_df, summarised_df

# %% [markdown]
# ## Run

# %%
#L01-1, L01-2, ... L01-4, L02-1, ... L11-4
lines = ['L01', 'L02', 'L03', 'L04', 'L05', 'L06', 'L07', 'L08', 'L09', 'L10', 'L11']
#lines = ['L01', 'L02']
lines = [f'{line}-{i}' for line in lines for i in range(1, 5)]
gen_id = [1, 2, 3]

tmp_dir = os.path.join("tmp", "essential_gene_blast_identification")
query_fasta = os.path.join(tmp_dir, "mds42_ess.fasta")
create_query_fasta(essential_genes, mds42_fasta, query_fasta)

# lines for every gen-id
line_df = pd.DataFrame({'line': np.repeat(lines, len(gen_id)), 'gen_id': np.tile(gen_id, len(lines))})
merged_df, sumamrised_df = identify_ess_genes(line_df, query_fasta, essential_genes, base_output_dir, tmp_dir)
# Out:
# Building a new DB, current time: 02/20/2025 16:16:11
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.1
# New DB title:  exp/multiple_runs14/tmp/L01-1/L01-1_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.030179 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:11
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.2
# New DB title:  exp/multiple_runs14/tmp/L01-1/L01-1_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0252168 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.3
# New DB title:  exp/multiple_runs14/tmp/L01-1/L01-1_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-1.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.023901 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.1
# New DB title:  exp/multiple_runs14/tmp/L01-2/L01-2_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.024796 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.2
# New DB title:  exp/multiple_runs14/tmp/L01-2/L01-2_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.024765 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.3
# New DB title:  exp/multiple_runs14/tmp/L01-2/L01-2_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-2.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.028291 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.1
# New DB title:  exp/multiple_runs14/tmp/L01-3/L01-3_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0250719 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.2
# New DB title:  exp/multiple_runs14/tmp/L01-3/L01-3_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.024564 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.3
# New DB title:  exp/multiple_runs14/tmp/L01-3/L01-3_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-3.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.024406 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:12
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.1
# New DB title:  exp/multiple_runs14/tmp/L01-4/L01-4_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0246282 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.2
# New DB title:  exp/multiple_runs14/tmp/L01-4/L01-4_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.026711 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.3
# New DB title:  exp/multiple_runs14/tmp/L01-4/L01-4_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L01-4.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0260119 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.1
# New DB title:  exp/multiple_runs14/tmp/L02-1/L02-1_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0233419 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.2
# New DB title:  exp/multiple_runs14/tmp/L02-1/L02-1_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0282888 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.3
# New DB title:  exp/multiple_runs14/tmp/L02-1/L02-1_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-1.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0240059 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.1
# New DB title:  exp/multiple_runs14/tmp/L02-2/L02-2_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.023663 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.2
# New DB title:  exp/multiple_runs14/tmp/L02-2/L02-2_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0233781 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.3
# New DB title:  exp/multiple_runs14/tmp/L02-2/L02-2_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-2.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0251241 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:13
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.1
# New DB title:  exp/multiple_runs14/tmp/L02-3/L02-3_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.023154 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:14
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.2
# New DB title:  exp/multiple_runs14/tmp/L02-3/L02-3_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0232019 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:14
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.3
# New DB title:  exp/multiple_runs14/tmp/L02-3/L02-3_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-3.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0241139 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:14
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-4.1
# New DB title:  exp/multiple_runs14/tmp/L02-4/L02-4_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-4.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0235791 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:14
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-4.2
# New DB title:  exp/multiple_runs14/tmp/L02-4/L02-4_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02-4.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.022835 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:14
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L02
1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0234461 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:25
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-2.2
# New DB title:  exp/multiple_runs14/tmp/L11-2/L11-2_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-2.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.02422 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-2.3
# New DB title:  exp/multiple_runs14/tmp/L11-2/L11-2_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-2.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.024081 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.1
# New DB title:  exp/multiple_runs14/tmp/L11-3/L11-3_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.023761 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.2
# New DB title:  exp/multiple_runs14/tmp/L11-3/L11-3_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0240409 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.3
# New DB title:  exp/multiple_runs14/tmp/L11-3/L11-3_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-3.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0234962 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.1
# New DB title:  exp/multiple_runs14/tmp/L11-4/L11-4_genome.1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.029763 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.2
# New DB title:  exp/multiple_runs14/tmp/L11-4/L11-4_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0247641 seconds.
#
#
#
#
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.3
# New DB title:  exp/multiple_runs14/tmp/L11-4/L11-4_genome.3.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L11-4.3
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0254512 seconds.

# %%
merged_df.to_csv(os.path.join(data_export_dir, f'{file_name_base}essential_gene_pos.csv'), index=False)

# %% [markdown]
# ## Result (no missing)

# %%
# all essential genes are found in the list
sumamrised_df.query("duplicated_genes > 0 | missing_genes > 0")
# Out:
#       line  gen_id  duplicated_genes  missing_genes
# 4    L01-2       2                 2              0
# 5    L01-2       3                 2              0
# 11   L01-4       3                 2              0
# 14   L02-1       3                13              0
# 16   L02-2       2                 2              0
# 17   L02-2       3                14              0
# 20   L02-3       3                 9              0
# 23   L02-4       3                 3              0
# 29   L03-2       3                 7              0
# 34   L03-4       2                 3              0
# 35   L03-4       3                 3              0
# 37   L04-1       2                 4              0
# 43   L04-3       2                10              0
# 44   L04-3       3                 6              0
# 46   L04-4       2                 1              0
# 47   L04-4       3                 4              0
# 58   L05-4       2                 2              0
# 68   L06-3       3                 6              0
# 91   L08-3       2                11              0
# 92   L08-3       3                11              0
# 112  L10-2       2                 2              0
# 116  L10-3       3                33              0
# 124  L11-2       2                 5              0
# 125  L11-2       3                 5              0
# 131  L11-4       3                19              0

# %% [markdown]
# ## Test run (L04-3)

# %%
# L04-3 should have duplicated essential genes. I use this to test the code
line_id = 'L04-3'
gen_id = 2
res_csv_ = run_ess_blast(f'{line_id}.{gen_id}',\
	os.path.join(base_output_dir, "tmp", line_id, f'{line_id}_genome.{gen_id}.fasta'),\
	query_fasta, tmp_dir)

res_ess_ = pd.read_csv(res_csv_, sep='\t')
res_ess_.head()
# Out:
# Building a new DB, current time: 02/20/2025 16:16:26
# New DB name:   /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L04-3.2
# New DB title:  exp/multiple_runs14/tmp/L04-3/L04-3_genome.2.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/kanai/documents/analysis/myTELR/syri/ipynb/tmp/essential_gene_blast_identification/blastdb/L04-3.2
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.0272238 seconds.
#   qseqid        sseqid  pident  length  mismatch  gapopen  qstart  qend  \
# 0   ribF  L04-3_G08_v2   100.0     941         0        0       1   941
# 1   ileS  L04-3_G08_v2   100.0    2816         0        0       1  2816
# 2   lspA  L04-3_G08_v2   100.0     494         0        0       1   494
# 3   ispH  L04-3_G08_v2   100.0     950         0        0       1   950
# 4   dapB  L04-3_G08_v2   100.0     821         0        0       1   821
#
#    sstart    send  evalue  bitscore  qlen
# 0  575672  576612     0.0      1738   941
# 1  576656  579471     0.0      5201  2816
# 2  579472  579965     0.0       913   494
# 3  580542  581491     0.0      1755   950
# 4  582639  583459     0.0      1517   821

# %%
res_ess_['is_duplicated'] = res_ess_.duplicated(subset=['qseqid'], keep=False)
unique_hits = res_ess_[~res_ess_['is_duplicated']]

duplicated_genes = res_ess_[res_ess_['is_duplicated']]['qseqid'].unique()
missing_genes = essential_genes[~essential_genes['gene'].isin(res_ess_['qseqid'])]

print(f"Number of unique hits: {len(unique_hits)}")
print(f"Number of missed essential genes: {len(missing_genes)}")
print(f"Number of duplicated hits: {len(duplicated_genes)}")
# Out:
# Number of unique hits: 292
# Number of missed essential genes: 0
# Number of duplicated hits: 10

# %% [markdown]
# # Calculate average distance from the closest essential gene
#
# For a region to be deleted by NE type IS deletion(recombination between Newly inserted IS with a preExisting one), which was the majority in Lee 2016,
# the region must be non-essential.
#
# Here, I identify if the local hopping is due to the distribution of essential genes
# or due to an innate property of the IS.

# %%
# by chatgpt
import pandas as pd

# Function to find the closest essential gene and IS end
def find_closest_gene(is_row, genes_df):
    # Initialize minimum distance and details for the closest approach
    min_distance = float('inf')
    closest_gene = None
    gene_end = None
    is_end_involved = None
    
    for _, gene_row in genes_df.iterrows():
        # Distances from IS start and end to both ends of the gene
        distances = {
            ('5_prime', 'start'): abs(is_row['start'] - gene_row['sstart']),
            ('5_prime', 'end'): abs(is_row['end'] - gene_row['sstart']),
            ('3_prime', 'start'): abs(is_row['start'] - gene_row['send']),
            ('3_prime', 'end'): abs(is_row['end'] - gene_row['send'])
        }
        
        # Identify the minimum distance and corresponding details
        for (gene_side, is_side), distance in distances.items():
            if distance < min_distance:
                min_distance = distance
                closest_gene = gene_row['gene']
                gene_end = gene_side
                is_end_involved = is_side
                position = gene_row['sstart'] if gene_side == '5_prime' else gene_row['send']
                
    # Return details including which IS end (start or end) is closest to the gene
    return pd.Series([closest_gene, gene_end, is_end_involved, min_distance, position],\
			 index=['closest_gene', 'gene_end', 'IS_end', 'distance', 'position'])

# %%
# test
is_df = is_positions_df.query("line == 'L04-3' and gen_id == 2")
essential_genes_df = merged_df.query("line == 'L04-3' and gen_id == 2")

# Apply the function to each IS row
#is_df[['closest_gene', 'gene_end', 'is_end','distance']] = is_df.apply(find_closest_gene, genes_df=essential_genes_df, axis=1)
# use loc
is_df.loc[:, ['closest_gene', 'gene_end', 'IS_end','distance', 'position']] = \
	is_df.apply(find_closest_gene, genes_df=essential_genes_df, axis=1)
is_df.head()
# Out:
#       start     end IS_strand  max_alignment_length  length  cluster_id  \
# 841   42391   45482   reverse                  3093    3092           0
# 842  121558  124650   forward                  3093    3093           1
# 843  355703  358793   reverse                  3092    3091           2
# 844  444530  447621   reverse                  3092    3092           3
# 845  552106  555198   reverse                  3093    3093           4
#
#       line  gen_id closest_gene gene_end IS_end  distance  position
# 841  L04-3       2          rho  3_prime  start       466     41925
# 842  L04-3       2         polA  5_prime    end      2763    127413
# 843  L04-3       2          ssb  3_prime  start       608    355095
# 844  L04-3       2          ppa  5_prime    end     10760    458381
# 845  L04-3       2         ribF  5_prime    end     20474    575672

# %%
essential_genes_df
# Out:
#        gene  pident  length  mismatch  gapopen  qstart  qend   sstart  \
# 13053  mukB   100.0    4460         0        0       1  4460  1418217
# 13054  rpoC   100.0    4223         0        0       1  4223   265789
# 13055  rpoB   100.0    4028         0        0       1  4028   261684
# 13056  ftsK   100.0    3989         0        0       1  3989  1929242
# 13057  ftsK   100.0    3989         0        0       1  3989  1372014
# ...     ...     ...     ...       ...      ...     ...   ...      ...
# 13360  hisR   100.0      76         0        0       1    76    59860
# 13361  trpT   100.0      75         0        0       1    75    21211
# 13362  thrU   100.0      75         0        0       1    75   255827
# 13363  glyT   100.0      74         0        0       1    74   256112
# 13364  cysT   100.0      73         0        0       1    73  2593160
#
#           send        evalue  bitscore  qlen   line  gen_id  duplicated
# 13053  1422676  0.000000e+00      8237  4460  L04-3       2       False
# 13054   270011  0.000000e+00      7799  4223  L04-3       2       False
# 13055   265711  0.000000e+00      7439  4028  L04-3       2       False
# 13056  1925254  0.000000e+00      7367  3989  L04-3       2        True
# 13057  1376002  0.000000e+00      7367  3989  L04-3       2        True
# ...        ...           ...       ...   ...    ...     ...         ...
# 13360    59935  6.390000e-35       141    76  L04-3       2       False
# 13361    21285  2.260000e-34       139    75  L04-3       2       False
# 13362   255901  2.260000e-34       139    75  L04-3       2       False
# 13363   256185  7.970000e-34       137    74  L04-3       2       False
# 13364  2593232  2.810000e-33       135    73  L04-3       2       False
#
# [312 rows x 15 columns]

# %%
import pandas as pd

# Example dataframes
# Assuming these are already defined: is_df and essential_genes_df

# Additional input
genome_size = 5000000  # Example genome size, adjust as necessary

def calculate_circular_distance(start, end, genome_size):
    """
    Calculate the shortest distance between two points in a circular genome.
    """
    direct_distance = abs(end - start)
    return min(direct_distance, genome_size - direct_distance)

def find_closest_genes_around_is(is_row, genes_df, genome_size):
    """
    Find the closest essential genes to both the 5' and 3' ends of an IS, considering circular genome.
    """
    # Initialize variables to track the closest genes and distances
    closest_gene_5_prime = None
    closest_gene_3_prime = None
    min_distance_5_prime = float('inf')
    min_distance_3_prime = float('inf')
    position_5_prime = None
    position_3_prime = None
    
    # Loop through each essential gene to find the closest to 5' and 3' ends of IS
    for _, gene_row in genes_df.iterrows():
        # For 5' end, consider genes at lower indexes (considering circularity)
        if gene_row['send'] < is_row['start']:
            distance_5_prime = calculate_circular_distance(gene_row['send'], is_row['start'], genome_size)
            if distance_5_prime < min_distance_5_prime:
                min_distance_5_prime = distance_5_prime
                closest_gene_5_prime = gene_row['gene']
                position_5_prime = gene_row['send']
        # For 3' end, consider genes at higher indexes (considering circularity)
        elif gene_row['sstart'] > is_row['end']:
            distance_3_prime = calculate_circular_distance(is_row['end'], gene_row['sstart'], genome_size)
            if distance_3_prime < min_distance_3_prime:
                min_distance_3_prime = distance_3_prime
                closest_gene_3_prime = gene_row['gene']
                position_3_prime = gene_row['sstart']
    
    return pd.Series([closest_gene_5_prime, position_5_prime, min_distance_5_prime, closest_gene_3_prime, position_3_prime, min_distance_3_prime],\
                     index=['closest_gene_5_prime', 'position_5_prime', 'distance_5_prime', 'closest_gene_3_prime', 'position_3_prime', 'distance_3_prime'])

# %%
# test I manually checked the first two is right.
is_df = is_positions_df.query("line == 'L04-3' and gen_id == 2")
essential_genes_df = merged_df.query("line == 'L04-3' and gen_id == 2 and not duplicated")[['gene', 'sstart', 'send']]
essential_genes_df = pd.concat([essential_genes_df,\
		pd.DataFrame({'gene': ['oriC', 'oriC'], 'sstart': [1, genome_size], 'send': [1, genome_size]})], ignore_index=True)

#is_df[['closest_gene_5_prime', 'position_5_prime', 'distance_5_prime', 'closest_gene_3_prime', 'position_3_prime', 'distance_3_prime']] = is_df.apply(find_closest_genes_around_is, genes_df=essential_genes_df, genome_size=genome_size, axis=1)
# use loc
is_df.loc[:, ['closest_gene_5_prime', 'position_5_prime', 'distance_5_prime', 'closest_gene_3_prime', 'position_3_prime', 'distance_3_prime']] = \
	is_df.apply(find_closest_genes_around_is, genes_df=essential_genes_df, genome_size=genome_size, axis=1)
is_df.head()
# Out:
#       start     end IS_strand  max_alignment_length  length  cluster_id  \
# 841   42391   45482   reverse                  3093    3092           0
# 842  121558  124650   forward                  3093    3093           1
# 843  355703  358793   reverse                  3092    3091           2
# 844  444530  447621   reverse                  3092    3092           3
# 845  552106  555198   reverse                  3093    3093           4
#
#       line  gen_id closest_gene_5_prime  position_5_prime  distance_5_prime  \
# 841  L04-3       2                  rho             41925               466
# 842  L04-3       2                 hemG            112499              9059
# 843  L04-3       2                  ssb            355095               608
# 844  L04-3       2                 rpsR            432628             11902
# 845  L04-3       2                 dnaT            516211             35895
#
#     closest_gene_3_prime  position_3_prime  distance_3_prime
# 841                 argX             59726             14244
# 842                 polA            127413              2763
# 843                 groS            377254             18461
# 844                  ppa            458381             10760
# 845                 ribF            575672             20474

# %%
# genome size should not matter much as deletions can't cover oriC
def find_closest_genes_around_is_batch(line_df, genome_sizes, merged_essential_genes, is_positions_df):
	output_df = pd.DataFrame()
	for _, row in line_df.iterrows():
		line_id = row['line']
		gen_id = row['gen_id']
		genome_size = genome_sizes.query(f"line == '{line_id}' and gen_id == {gen_id}")['genome_size'].values[0]

		essential_genes_df = merged_essential_genes.query(f"line == '{line_id}' and gen_id == {gen_id} and not duplicated")[['gene', 'sstart', 'send']]
		essential_genes_df = pd.concat([essential_genes_df,\
			pd.DataFrame({'gene': ['oriC', 'oriC'], 'sstart': [1, genome_size], 'send': [1, genome_size]})], ignore_index=True)

		is_df = is_positions_df.query(f"line == '{line_id}' and gen_id == {gen_id}")
		is_df.loc[:, ['closest_gene_5_prime', 'position_5_prime', 'distance_5_prime', 'closest_gene_3_prime', 'position_3_prime', 'distance_3_prime']] = \
			is_df.apply(find_closest_genes_around_is, genes_df=essential_genes_df, genome_size=genome_size, axis=1)

		output_df = pd.concat([output_df, is_df], ignore_index=True)
	return output_df

# %%
is_distance_df = find_closest_genes_around_is_batch(line_df, genome_sizes, merged_df, is_positions_df)
is_distance_df.to_csv(os.path.join(data_export_dir, file_name_base + 'closest_essential_genes.csv'))
is_distance_df.head()
# Out:
#      start      end IS_strand  max_alignment_length  length  cluster_id  \
# 0   476928   480020   reverse                  3093    3093           0
# 1   557167   560259   reverse                  3093    3093           1
# 2  1187831  1192502   forward                  3093    4672           2
# 3  1405123  1408215   forward                  3093    3093           3
# 4  1499230  1503892   reverse                  3093    4663           4
#
#     line  gen_id closest_gene_5_prime  position_5_prime  distance_5_prime  \
# 0  L01-1       1                 yjeE            470186              6742
# 1  L01-1       1                  ppa            526892             30275
# 2  L01-1       1                 leuS           1175771             12060
# 3  L01-1       1                 infA           1266184            138939
# 4  L01-1       1                  lnt           1496376              2854
#
#   closest_gene_3_prime  position_3_prime  distance_3_prime
# 0                 rpsR            503080             23060
# 1                 valS            561324              1065
# 2                 asnS           1205042             12540
# 3                 fldA           1476321             68106
# 4                 fabA           1519050             15158

# %% [markdown]
# ## Analyse results
# group by {line, gen_id} and calculate average, median merged {distance_5_prime, distance_3_prime}
# Merging the 5' and 3' prime distances into one column

# %%
merged_distances = pd.melt(is_distance_df, id_vars=['line', 'gen_id'], value_vars=['distance_5_prime', 'distance_3_prime'], 
                           var_name='prime_end', value_name='distance')

# Group by line and gen_id, then calculate average and median
grouped = merged_distances.groupby(['line', 'gen_id'])
avg_distance = grouped['distance'].mean().reset_index(name='average_distance')
median_distance = grouped['distance'].median().reset_index(name='median_distance')

# Calculating expected value
expected_value = grouped.apply(lambda x: x['distance'].pow(2).sum() / x['distance'].sum() / 2).reset_index(name='expected')

# Merging the results
is_distance_stats = avg_distance.merge(median_distance, on=['line', 'gen_id']).merge(expected_value, on=['line', 'gen_id'])
is_distance_stats.head(10)
# Out:
#     line  gen_id  average_distance  median_distance      expected
# 0  L01-1       1      37956.400000          14958.0  50612.642789
# 1  L01-1       2      46690.529412          18175.0  59806.225897
# 2  L01-1       3      30962.933333          18428.5  32979.744036
# 3  L01-2       1      37956.400000          14958.0  50612.642789
# 4  L01-2       2      32031.406250          14956.5  43147.040845
# 5  L01-2       3      35587.261905          14958.0  47751.338572
# 6  L01-3       1      37956.400000          14958.0  50612.642789
# 7  L01-3       2      42077.833333          21731.5  53974.845497
# 8  L01-3       3      35247.043478          19606.5  48134.267662
# 9  L01-4       1      37956.400000          14958.0  50612.642789

# %% [markdown]
# ## median of expected distance  (not used)

# %%
# median of expected distances
expected_distances = is_distance_stats.query('gen_id == 1 | gen_id == 2').\
	query('not(line == "L04-1" and gen_id == 2)').expected
print(np.percentile(is_distance_stats.query('gen_id == 1 | gen_id == 2').expected, 75) - np.percentile(is_distance_stats.query('gen_id == 1 | gen_id == 2').expected, 25))
# in text
print(f'The median (IQR) of the expected distances between IS elements and the closest essential genes is {np.median(expected_distances):.2f} ({np.percentile(expected_distances, 25):.2f}-{np.percentile(expected_distances, 75):.2f}).')
print(f'Number of genomes: {len(expected_distances)}')
# Out:
# 13591.567569477258
# The median (IQR) of the expected distances between IS elements and the closest essential genes is 41115.78 (37211.26-50612.64).
# Number of genomes: 87

# %% [markdown]
# ## median of expected median distance (not used)

# %%
# calculate the expected median
def calculate_expected_median(group):
    # Sort the group by distance
    sorted_group = group.sort_values(by='distance')
    
    # Calculate the cumulative sum of distances
    cumulative_sum = sorted_group['distance'].cumsum()
    
    # Total sum of distances for the group
    total_sum = cumulative_sum.iloc[-1]
    
    # Find the median value: where the cumulative sum reaches half of the total sum
    # At such point, half the events will be related to ISs with shorter distances and the other half with longer distances
    median_index = cumulative_sum[cumulative_sum >= total_sum / 2].index[0]
    weighted_median = sorted_group.loc[median_index, 'distance'] / 2
    
    return weighted_median

# Apply the weighted median calculation to each group
median_values = grouped.apply(calculate_expected_median).reset_index(name='weighted_median')

# Merging the weighted median with the previous results
final_results = is_distance_stats.merge(median_values, on=['line', 'gen_id'])

final_results.head()
# Out:
#     line  gen_id  average_distance  median_distance      expected  \
# 0  L01-1       1      37956.400000          14958.0  50612.642789
# 1  L01-1       2      46690.529412          18175.0  59806.225897
# 2  L01-1       3      30962.933333          18428.5  32979.744036
# 3  L01-2       1      37956.400000          14958.0  50612.642789
# 4  L01-2       2      32031.406250          14956.5  43147.040845
#
#    weighted_median
# 0          48877.0
# 1          58468.5
# 2          34049.5
# 3          48877.0
# 4          34051.0

# %%
# IQR of weighed medians
expected_distances = final_results.query('gen_id == 1 | gen_id == 2').\
	query('not(line == "L04-1" and gen_id == 2)').weighted_median
# in text
print(f'The median (IQR) of the expected distances between IS elements and the closest essential genes is:')
print(f'{np.median(expected_distances):.2f} ({np.percentile(expected_distances, 25):.2f}-{np.percentile(expected_distances, 75):.2f}).')
print(f'Number of genomes: {len(expected_distances)}')
# Out:
# The median (IQR) of the expected distances between IS elements and the closest essential genes is:
# 34318.50 (32818.50-48877.00).
# Number of genomes: 87

# %% [markdown]
# ## Expected median deletions by normalizing the weights for each genome

# %%
# merged_disatnces : raw data of distance to essential genes
merged_distances_median = merged_distances.query('gen_id == 1 | gen_id == 2').\
	query('not(line == "L04-1" and gen_id == 2)').\
	sort_values(by='distance')

# %%
# Calculate initial weights based on distance
merged_distances_median['initial_weight'] = merged_distances_median['distance'] -20

# Determine factors based on gen_id (8 for gen_id = 1, 12 for gen_id = 2)
merged_distances_median['factor'] = np.where(merged_distances_median['gen_id'] == 1, 8, 12)

# Group by 'line' and 'gen_id', and calculate the sum of weights for normalization
grouped_weights = merged_distances_median.groupby(['line', 'gen_id'])['initial_weight'].transform('sum')

# Normalize weights within each group and apply factor
merged_distances_median['normalized_weight'] = (1.0 / grouped_weights) * merged_distances_median['factor']

# Print DataFrame to see the normalized weights
print(merged_distances_median)
# Out:
#        line  gen_id         prime_end  distance  initial_weight  factor  \
# 1869  L09-2       1  distance_5_prime        23               3       8
# 1838  L09-1       2  distance_5_prime        23               3      12
# 1879  L09-2       2  distance_5_prime        23               3      12
# 1825  L09-1       1  distance_5_prime        23               3       8
# 1968  L09-4       2  distance_5_prime        23               3      12
# ...     ...     ...               ...       ...             ...     ...
# 1753  L08-3       2  distance_5_prime    323389          323369      12
# 4138  L08-3       2  distance_3_prime    333417          333397      12
# 853   L04-3       2  distance_5_prime    340675          340655      12
# 854   L04-3       2  distance_5_prime    345597          345577      12
# 4137  L08-3       2  distance_3_prime    623471          623451      12
#
#       normalized_weight
# 1869           0.000012
# 1838           0.000013
# 1879           0.000015
# 1825           0.000011
# 1968           0.000016
# ...                 ...
# 1753           0.000005
# 4138           0.000005
# 853            0.000004
# 854            0.000004
# 4137           0.000005
#
# [2652 rows x 7 columns]

# %% [markdown]
# ### Save weight data

# %%
#merged_distances_median.to_csv(os.path.join(data_export_dir, file_name_base + "essential_gene_distance_weighted.csv"))

# %%
# Calculate cumulative weight to find the median
# This approach assumes uniform distribution of deletion sizes from 1 to distance
merged_distances_median['cumulative_weight_rv'] = merged_distances_median.loc[::-1, 'normalized_weight'].cumsum()[::-1]
merged_distances_median.head()
# Out:
#        line  gen_id         prime_end  distance  initial_weight  factor  \
# 1869  L09-2       1  distance_5_prime        23               3       8
# 1838  L09-1       2  distance_5_prime        23               3      12
# 1879  L09-2       2  distance_5_prime        23               3      12
# 1825  L09-1       1  distance_5_prime        23               3       8
# 1968  L09-4       2  distance_5_prime        23               3      12
#
#       normalized_weight  cumulative_weight_rv
# 1869           0.000012              0.022196
# 1838           0.000013              0.022184
# 1879           0.000015              0.022171
# 1825           0.000011              0.022156
# 1968           0.000016              0.022145

# %%
# Grouping by 'distance' and summarizing
merged_distances_median_grouped = merged_distances_median.groupby('distance').agg({
    'line': 'first',
    'gen_id': 'first',
    'prime_end': 'first',
    'normalized_weight': 'sum',
    'line': 'count'  # Adding count of the grouped entries
}).rename(columns={'line': 'count'}).\
    sort_values(by='distance').reset_index()

merged_distances_median_grouped['cumulative_weight_rv'] = merged_distances_median_grouped.loc[::-1, 'normalized_weight'].cumsum()[::-1]
# Calculating differences in 'distance' from the previous 'distance' value
min_dist = merged_distances_median_grouped['distance'].min()
merged_distances_median_grouped['distance_diff'] = merged_distances_median_grouped['distance'].diff().fillna(min_dist - 20)
merged_distances_median_grouped = merged_distances_median_grouped.assign(prod_cwr = lambda df: df.cumulative_weight_rv * df.distance_diff)
merged_distances_median_grouped['cumulative_cwr'] = merged_distances_median_grouped.prod_cwr.cumsum()
total_cwr = merged_distances_median_grouped.prod_cwr.sum()
merged_distances_median_grouped['cumulative_cwr'] = merged_distances_median_grouped['cumulative_cwr'] / total_cwr

median_row = merged_distances_median_grouped[merged_distances_median_grouped['cumulative_cwr'] > 0.5].iloc[0]

merged_distances_median_grouped.tail()
# Out:
#       distance  count  gen_id         prime_end  normalized_weight  \
# 1413    323389      1       2  distance_5_prime           0.000005
# 1414    333417      1       2  distance_3_prime           0.000005
# 1415    340675      1       2  distance_5_prime           0.000004
# 1416    345597      1       2  distance_5_prime           0.000004
# 1417    623471      1       2  distance_3_prime           0.000005
#
#       cumulative_weight_rv  distance_diff  prod_cwr  cumulative_cwr
# 1413              0.000022        44273.0  0.968069        0.998086
# 1414              0.000017        10028.0  0.170117        0.998282
# 1415              0.000012         7258.0  0.087550        0.998383
# 1416              0.000008         4922.0  0.041749        0.998431
# 1417              0.000005       277874.0  1.362050        1.000000

# %%
merged_distances_median_grouped.head()
# Out:
#    distance  count  gen_id         prime_end  normalized_weight  \
# 0        23      8       1  distance_5_prime           0.000099
# 1        45      8       2  distance_3_prime           0.000074
# 2       236      8       2  distance_3_prime           0.000064
# 3       327      1       2  distance_3_prime           0.000010
# 4       349      1       2  distance_5_prime           0.000007
#
#    cumulative_weight_rv  distance_diff  prod_cwr  cumulative_cwr
# 0              0.022196            3.0  0.066589        0.000077
# 1              0.022097           22.0  0.486134        0.000637
# 2              0.022023          191.0  4.206484        0.005483
# 3              0.021959           91.0  1.998276        0.007785
# 4              0.021949           22.0  0.482888        0.008341

# %%
median_dist = ((median_row.distance - (median_row.cumulative_cwr - 0.5) / median_row.prod_cwr * median_row.distance_diff))
median_dist
# Out:
# 29915.982584326164

# %%
import pandas as pd
import numpy as np
from scipy.stats import bootstrap

# Function to perform the analysis and return the median distance
def perform_analysis(df):
    # Grouping by 'distance' and summarizing
    grouped = df.groupby('distance').agg({
        'line': 'first',
        'gen_id': 'first',
        'prime_end': 'first',
        'normalized_weight': 'sum',
        'line': 'count'  # Adding count of the grouped entries
    }).rename(columns={'line': 'count'}).\
        sort_values(by='distance').reset_index()

    grouped['cumulative_weight_rv'] = grouped.loc[::-1, 'normalized_weight'].cumsum()[::-1]

    # Calculating differences in 'distance' from the previous 'distance' value
    min_dist = grouped['distance'].min()
    grouped['distance_diff'] = grouped['distance'].diff().fillna(min_dist - 20)
    grouped = grouped.assign(prod_cwr=lambda df: df.cumulative_weight_rv * df.distance_diff)
    grouped['cumulative_cwr'] = grouped.prod_cwr.cumsum()
    total_cwr = grouped.prod_cwr.sum()

    median_row = grouped[grouped['cumulative_cwr'] > total_cwr / 2].iloc[0]
    median_dist = ((median_row.distance - (median_row.cumulative_cwr - total_cwr / 2) / median_row.prod_cwr * median_row.distance_diff) ) 

    return median_dist

# Function to perform bootstrapping using the BCa method
def bootstrap_bca_analysis(df, n_resamples=1000):
    # Define a function for use with bootstrap that performs the analysis
    def compute_median(indices):
        sampled_df = df.iloc[indices]
        return perform_analysis(sampled_df)

    # Perform bootstrap with BCa method
    res = bootstrap((np.arange(len(df)),), statistic=compute_median, 
                    n_resamples=n_resamples, method='BCa', vectorized=False)
    return res.confidence_interval

# Perform bootstrapping and print the confidence interval
confidence_interval = bootstrap_bca_analysis(merged_distances_median)

print("BCa Confidence Interval for the Weighted Median of Distance:", confidence_interval)
# Out:
# BCa Confidence Interval for the Weighted Median of Distance: ConfidenceInterval(low=28348.905591573814, high=31484.249253033817)
